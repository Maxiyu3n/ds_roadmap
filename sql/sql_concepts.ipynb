# %%
# 1. how many joins we have and define each one (inner, outer, left outer, right outer, full join)

# %% [markdown]
# Inner join returns rows only when there is a match in both tables.
# left join Returns all rows from the left table, and matched rows from the right.
# full join: Returns all rows from both tables. If there's a match, rows are joined. If not, NULLs fill in where no match exists.
# cross join: Returns the Cartesian product of both tables — every row of A paired with every row of B.

# %%
# 2. what is a foreign key? how is it used?

# %% [markdown]
# A foreign key in SQL is a column or a set of columns in one table that is used to establish a link between the data in two tables. It acts as a reference to the primary key in another table

# %%
# 3. what is a primary key?

# %% [markdown]
# A primary key is used to uniquely identify each row in a table.

# %%
# 4. what's the difference between where and having clauses?

# %% [markdown]
# where: filter row before aggregation/ individual rows, having: Filtering groups after aggregation/ grouped results

# %%
# 5. what are window function, and how do they differ from aggregate functions?

# %% [markdown]
# Window functions perform calculations across a set of related rows, but unlike aggregate functions, they do not collapse rows. Instead, they return a value for each row, while still having access to data from a defined "window" or group.
#
# Use aggregate functions when you want group-level summaries.
#
# Use window functions when you need row-level data with group-level context.
